# %%
l = [1,2,3,4,5,5]

# %%
len(l)
# Out:
# 5

# %%
for i in range(0,len(l)-1):
    print(l[i])
# Out:
# 1
# 2
# 3
# 4

# %%
l
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
a = [1,2,3]

# %%
l.append(a)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 5, [1, 2, 3]]

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints；
	for i in range(0,len(points)-1):
		if is_intersected(A, B, points[i], points[i+1]):
			p = findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss[0] = s1;
ss[1] = s2;
ss[2] = s3;
for i in rang(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
#   File "<ipython-input-12-64566663fcb2>", line 58
#     points = street.streetPoints；
#                                 ^
# SyntaxError: invalid character in identifier

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if is_intersected(A, B, points[i], points[i+1]):
			p = findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss[0] = s1;
ss[1] = s2;
ss[2] = s3;
for i in rang(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# ------------------------------------------------------------------------
# IndexError                             Traceback (most recent call last)
# <ipython-input-16-a1b37794e4a5> in <module>()
#     116 s3 = 'a "daven" (1,4) (5,8)'
#     117 ss = [];
# --> 118 ss[0] = s1;
#     119 ss[1] = s2;
#     120 ss[2] = s3;
#
# IndexError: list assignment index out of range

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if is_intersected(A, B, points[i], points[i+1]):
			p = findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "daven" ['(1,4)', '(5,8)']

# %%
streetList
# Out:
# [<__main__.Street at 0x1100b6b00>,
#  <__main__.Street at 0x1100b6be0>,
#  <__main__.Street at 0x1100b6c50>]

# %%
for i in streetList:
    print(i.streetName)
# Out:
# "weber"
# "king"
# "daven"

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if is_intersected(A, B, points[i], points[i+1]):
			p = findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)


vertexPointSet=[];
for i,s in enumerate(streetList):
	if i == (len(streetList) -1):break;
	points = s.streetPoints;
	for i in range(0,len(points)-1):
		v = findVertex(points[i],points[i+1],streetList[i+1])
		for i in range(0,len(v)):
			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "daven" ['(1,4)', '(5,8)']
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-21-6bb94fe7e29b> in <module>()
#     137         points = s.streetPoints;
#     138         for i in range(0,len(points)-1):
# --> 139                 v = findVertex(points[i],points[i+1],streetList[i+1])
#     140                 for i in range(0,len(v)):
#     141                         vertexPointSet.append(v[i]);
#
# <ipython-input-21-6bb94fe7e29b> in findVertex(A, B, street)
#      58         points = street.streetPoints
#      59         for i in range(0,len(points)-1):
# ---> 60                 if is_intersected(A, B, points[i], points[i+1]):
#      61                         p = findIntersectionPoint(A,B,C,D);
#      62                         vex.append(p);
#
# NameError: name 'is_intersected' is not defined

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)


vertexPointSet=[];
for i,s in enumerate(streetList):
	if i == (len(streetList) -1):break;
	points = s.streetPoints;
	for i in range(0,len(points)-1):
		v = findVertex(points[i],points[i+1],streetList[i+1])
		for i in range(0,len(v)):
			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "daven" ['(1,4)', '(5,8)']
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-23-0f83017ed749> in <module>()
#     137         points = s.streetPoints;
#     138         for i in range(0,len(points)-1):
# --> 139                 v = findVertex(points[i],points[i+1],streetList[i+1])
#     140                 for i in range(0,len(v)):
#     141                         vertexPointSet.append(v[i]);
#
# <ipython-input-23-0f83017ed749> in findVertex(A, B, street)
#      58         points = street.streetPoints
#      59         for i in range(0,len(points)-1):
# ---> 60                 if IS.is_intersected(A, B, points[i], points[i+1]):
#      61                         p = IS.findIntersectionPoint(A,B,C,D);
#      62                         vex.append(p);
#
# /Users/luyi/650_again/intersection.py in is_intersected(A, B, C, D)
#      28 def is_intersected(A, B, C, D):
#      29     '''A, B, C, D 为 Point 类型'''
# ---> 30     AC = Vector(A, C)
#      31     AD = Vector(A, D)
#      32     BC = Vector(B, C)
#
# /Users/luyi/650_again/intersection.py in __init__(self, start_point, end_point)
#      13     def __init__(self, start_point, end_point):
#      14         self.start_point, self.end_point = start_point, end_point
# ---> 15         self.x = end_point.x - start_point.x
#      16         self.y = end_point.y - start_point.y
#      17
#
# AttributeError: 'str' object has no attribute 'x'

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)



def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pointList = s_list[2:];
	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)

A = streetList[0].streetPoints[0];
B = streetList[0].streetPoints[1];
print(A,B)
# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "weber" ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']
# "king" ['(4,2)', '(4,8)']
# "daven" ['(1,4)', '(5,8)']
# (2,-1) (2,2)

# %%
l = streetList[1].streetPoints

# %%
l
# Out:
# ['(4,2)', '(4,8)']

# %%
C = l[0];

# %%
D = l[1]

# %%
IS.is_intersected(A, B, C, D)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-31-55aef648d5e9> in <module>()
# ----> 1 IS.is_intersected(A, B, C, D)
#
# /Users/luyi/650_again/intersection.py in is_intersected(A, B, C, D)
#      28 def is_intersected(A, B, C, D):
#      29     '''A, B, C, D 为 Point 类型'''
# ---> 30     AC = Vector(A, C)
#      31     AD = Vector(A, D)
#      32     BC = Vector(B, C)
#
# /Users/luyi/650_again/intersection.py in __init__(self, start_point, end_point)
#      13     def __init__(self, start_point, end_point):
#      14         self.start_point, self.end_point = start_point, end_point
# ---> 15         self.x = end_point.x - start_point.x
#      16         self.y = end_point.y - start_point.y
#      17
#
# AttributeError: 'str' object has no attribute 'x'

# %%
type(A)
# Out:
# str

# %%
type(C)
# Out:
# str

# %%
A =IS.Point(streetList[0].streetPoints[0]);
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# <ipython-input-34-56e0ba71cad7> in <module>()
# ----> 1 A =IS.Point(streetList[0].streetPoints[0]);
#
# TypeError: __init__() missing 1 required positional argument: 'y'

# %%
A
# Out:
# '(2,-1)'

# %%
str = (1,2)

# %%
str[1:-1]
# Out:
# ()

# %%
str(1,-1)
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# <ipython-input-39-149dd50912b9> in <module>()
# ----> 1 str(1,-1)
#
# TypeError: 'tuple' object is not callable

# %%
str(1)
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# <ipython-input-40-dd09b06c39ba> in <module>()
# ----> 1 str(1)
#
# TypeError: 'tuple' object is not callable

# %%
str[1]
# Out:
# 2

# %%
str
# Out:
# (1, 2)

# %%
str
# Out:
# (1, 2)

# %%
str[0:1]
# Out:
# (1,)

# %%
str
# Out:
# (1, 2)

# %%
str[0]
# Out:
# 1

# %%
str = '(1,2)'

# %%
str[1:-1]
# Out:
# '1,2'

# %%
a = '2'

# %%
str2num(a)
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-53-433c4ac802f1> in <module>()
# ----> 1 str2num(a)
#
# NameError: name 'str2num' is not defined

# %%
a
# Out:
# '2'

# %%
float(a)
# Out:
# 2.0

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in range(0,len(pl)):
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)

A =Point(streetList[0].streetPoints[0]);
B = streetList[0].streetPoints[1];
print(A,B)

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-56-29a2601a746d> in <module>()
#     129 ss.append(s3);
#     130 for i in range(0,len(ss)):
# --> 131         command,str,pointList = readInput(ss[i]);
#     132         if command == 'a':
#     133                 streetList.append(a(str,pointList));
#
# <ipython-input-56-29a2601a746d> in readInput(s)
#     101         pointList = [];
#     102         for pointStr in range(0,len(pl)):
# --> 103                 pointList.append(point_str2class(pointStr));
#     104
#     105
#
# <ipython-input-56-29a2601a746d> in point_str2class(str)
#      90
#      91 def point_str2class(str):
# ---> 92         a,b = str.split(',');
#      93         x,y = float(a),float(b);
#      94         return IS.Point(x,y);
#
# AttributeError: 'int' object has no attribute 'split'

# %%
str = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'

# %%
l = str.split(' ')

# %%
l
# Out:
# ['a', '"weber"', '(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']

# %%
type(l[0])
# Out:
# str

# %%
type(l[2])
# Out:
# str

# %%
pl = l[2:]

# %%
pl
# Out:
# ['(2,-1)', '(2,2)', '(5,5)', '(5,6)', '(3,8)']

# %%
	for pointStr in pl:
		print(type(pointStr));
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
range(0,len(pl))
# Out:
# range(0, 5)

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)

A =Point(streetList[0].streetPoints[0]);
B = streetList[0].streetPoints[1];
print(A,B)

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-69-0e14a9de2d45> in <module>()
#     129 ss.append(s3);
#     130 for i in range(0,len(ss)):
# --> 131         command,str,pointList = readInput(ss[i]);
#     132         if command == 'a':
#     133                 streetList.append(a(str,pointList));
#
# <ipython-input-69-0e14a9de2d45> in readInput(s)
#     101         pointList = [];
#     102         for pointStr in pl:
# --> 103                 pointList.append(point_str2class(pointStr));
#     104
#     105
#
# <ipython-input-69-0e14a9de2d45> in point_str2class(str)
#      91 def point_str2class(str):
#      92         a,b = str.split(',');
# ---> 93         x,y = float(a),float(b);
#      94         return IS.Point(x,y);
#      95
#
# ValueError: could not convert string to float: '(2'

# %%
s = '(1,2)'

# %%
s[1:-1]
# Out:
# '1,2'

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,s.streetPoints)

A =Point(streetList[0].streetPoints[0]);
B = streetList[0].streetPoints[1];
print(A,B)

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" [<intersection.Point object at 0x11016c438>, <intersection.Point object at 0x11016c3c8>, <intersection.Point object at 0x11016c470>, <intersection.Point object at 0x11016c4a8>, <intersection.Point object at 0x11016c4e0>]
# "weber" [<intersection.Point object at 0x11016c438>, <intersection.Point object at 0x11016c3c8>, <intersection.Point object at 0x11016c470>, <intersection.Point object at 0x11016c4a8>, <intersection.Point object at 0x11016c4e0>]
# "king" [<intersection.Point object at 0x11016c320>, <intersection.Point object at 0x11016c390>]
# "weber" [<intersection.Point object at 0x11016c438>, <intersection.Point object at 0x11016c3c8>, <intersection.Point object at 0x11016c470>, <intersection.Point object at 0x11016c4a8>, <intersection.Point object at 0x11016c4e0>]
# "king" [<intersection.Point object at 0x11016c320>, <intersection.Point object at 0x11016c390>]
# "daven" [<intersection.Point object at 0x11016c358>, <intersection.Point object at 0x11016c5c0>]
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-72-a8d9ae364dc8> in <module>()
#     141                 print(s.streetName,s.streetPoints)
#     142
# --> 143 A =Point(streetList[0].streetPoints[0]);
#     144 B = streetList[0].streetPoints[1];
#     145 print(A,B)
#
# NameError: name 'Point' is not defined

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));

# A =Point(streetList[0].streetPoints[0]);
# B = streetList[0].streetPoints[1];
# print(A,B)

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>

# %%
x = 1,y =2
# Out:
#   File "<ipython-input-74-2b63b071073a>", line 1
#     x = 1,y =2
#        ^
# SyntaxError: can't assign to literal

# %%
x = 1

# %%
y =2

# %%
print('(',x,',',y,')');
# Out:
# ( 1 , 2 )

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));
s = streetList[0];
print(s.streetName);
for p in s.streetPoints:
	print(p.toString());

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>
# "weber"
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-78-7ba93d379165> in <module>()
#     143 print(s.streetName);
#     144 for p in s.streetPoints:
# --> 145         print(p.toString());
#     146
#     147 # a = findVertex(A,B,streetList[1])
#
# AttributeError: 'Point' object has no attribute 'toString'

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));
s = streetList[0];
print(s.streetName);
for p in s.streetPoints:
	print(toString(p));

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>
# "weber"
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-80-91ec163328c6> in <module>()
#     143 print(s.streetName);
#     144 for p in s.streetPoints:
# --> 145         print(toString(p));
#     146
#     147 # a = findVertex(A,B,streetList[1])
#
# NameError: name 'toString' is not defined

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));
s = streetList[0];
print(s.streetName);
for p in s.streetPoints:
	print(p);

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>
# "weber"
# <intersection.Point object at 0x1101f2208>
# <intersection.Point object at 0x1101f2160>
# <intersection.Point object at 0x1101f2240>
# <intersection.Point object at 0x1101f2278>
# <intersection.Point object at 0x1101f22b0>

# %%
class Point(object):

    def __init__(self, x, y):
        self.x, self.y = x, y

    def __str__(self):
        return "(%d,%d)"%(self.x,self.y)

# %%
a = Point(1,2)

# %%
type(a)
# Out:
# __main__.Point

# %%
print(a)
# Out:
# (1,2)

# %%
class Point(object):

    def __init__(self, x, y):
        self.x, self.y = x, y

    def __str__(self):
        return "(" + str(self.x) + str(self.y),")";

# %%
class Point(object):

    def __init__(self, x, y):
        self.x, self.y = x, y

    def __str__(self):
        return "(" + %d + %d,")"%(self.x,self.y)
# Out:
#   File "<ipython-input-98-e3bfe9af1ab6>", line 7
#     return "(" + %d + %d,")"%(self.x,self.y)
#                  ^
# SyntaxError: invalid syntax

# %%
class Point(object):

    def __init__(self, x, y):
        self.x, self.y = x, y

    def __str__(self):
        return "(+ %d + %d)"%(self.x,self.y)

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));
s = streetList[0];
print(s.streetName);
for p in s.streetPoints:
	print(p);

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>
# "weber"
# <intersection.Point object at 0x11010abe0>
# <intersection.Point object at 0x11010ac88>
# <intersection.Point object at 0x11010ada0>
# <intersection.Point object at 0x11010add8>
# <intersection.Point object at 0x11010ae10>

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,type(s.streetPoints));
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# "weber" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "weber" <class 'list'>
# "king" <class 'list'>
# "daven" <class 'list'>
# "weber"
# <intersection.Point object at 0x110117588>

# %%
class Point(object):

    def __init__(self, x, y):
        self.x, self.y = x, y

    def __str__(self):
        return "(%d,%d)"%(self.x,self.y)

# %%
a = Point(1,2)

# %%
type(a)
# Out:
# __main__.Point

# %%
print(a)
# Out:
# (1,2)

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s.streetName,print(s.streetPoints));
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# [<intersection.Point object at 0x110117b38>, <intersection.Point object at 0x110117be0>, <intersection.Point object at 0x110117cf8>, <intersection.Point object at 0x110117d30>, <intersection.Point object at 0x110117d68>]
# "weber" None
# [<intersection.Point object at 0x110117b38>, <intersection.Point object at 0x110117be0>, <intersection.Point object at 0x110117cf8>, <intersection.Point object at 0x110117d30>, <intersection.Point object at 0x110117d68>]
# "weber" None
# [<intersection.Point object at 0x1101175f8>, <intersection.Point object at 0x110117630>]
# "king" None
# [<intersection.Point object at 0x110117b38>, <intersection.Point object at 0x110117be0>, <intersection.Point object at 0x110117cf8>, <intersection.Point object at 0x110117d30>, <intersection.Point object at 0x110117d68>]
# "weber" None
# [<intersection.Point object at 0x1101175f8>, <intersection.Point object at 0x110117630>]
# "king" None
# [<intersection.Point object at 0x1101172e8>, <intersection.Point object at 0x110117518>]
# "daven" None
# "weber"
# <intersection.Point object at 0x110117b38>

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;
	def __str__(self):
        return "(%s,%s)"%(self.streetName,self.streetPoints)

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
#   File "<ipython-input-114-2cd021b7cc85>", line 18
#     return "(%s,%s)"%(self.streetName,self.streetPoints)
#                                                         ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;
    def __str__(self):
        return "(%s,%s)"%(self.streetName,self.streetPoints);

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
#   File "<ipython-input-115-900cdab66b77>", line 17
#     def __str__(self):
#                       ^
# IndentationError: unindent does not match any outer indentation level

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;
    def __str__(self):
		return "(%s,%s)"%(self.streetName,self.streetPoints);

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
#   File "<ipython-input-116-cc1a0e854029>", line 17
#     def __str__(self):
#                       ^
# IndentationError: unindent does not match any outer indentation level

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));
		print(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# <intersection.Point object at 0x110183160>
# <intersection.Point object at 0x1101831d0>
# <intersection.Point object at 0x110183198>
# <intersection.Point object at 0x110183240>
# <intersection.Point object at 0x110183160>
# <__main__.Street object at 0x110187fd0>
# <intersection.Point object at 0x110117d68>
# <intersection.Point object at 0x110117438>
# <__main__.Street object at 0x110187fd0>
# <__main__.Street object at 0x110117b38>
# <intersection.Point object at 0x110183160>
# <intersection.Point object at 0x110183198>
# <__main__.Street object at 0x110187fd0>
# <__main__.Street object at 0x110117b38>
# <__main__.Street object at 0x110117c88>
# "weber"
# <intersection.Point object at 0x110183128>

# %%
import intersection as IS

# %%
a = IS.Point(1,2)

# %%
a = Point(1,2)

# %%
print(a)
# Out:
# (1,2)

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# <__main__.Street object at 0x1100db198>
# <__main__.Street object at 0x1100db198>
# <__main__.Street object at 0x1100db710>
# <__main__.Street object at 0x1100db198>
# <__main__.Street object at 0x1100db710>
# <__main__.Street object at 0x1100f5240>
# "weber"
# <intersection.Point object at 0x1100f5320>

# %%
import intersection as IS
import sys
import math
import numpy as np

class Vertex(object):

    def __init__(self, street, vertexPoint):
        self.street = street;
        self.vertexPoint = vertexPoint;

class Street(object):
	def __init__(self,streetName,streetPoints):
		self.streetName = streetName;
		self.streetPoints = streetPoints;
		# self.streetEdge = streetEdge;

class edge(object):
	def __init__(self,streetName,vertexPoint):
		self.streetName = streetName;
		self.vertexPoint = vertexPoint;

def a(str,list):
	return Street(str,list)

def c(streetList,str,list):
	for s in streetList:
		if s.streetName == str:
			s.streetPoints = list;

def r(streetList,str):
	for s in streetList:
		if s.streetName == str:
			streetList.remove(s);

def g():
	# 把所有点放在一个list里
	vertexPointSet = [];
	pointsAll = [];
	for s in streetList:
		p = s.streetPoints;
		for i in range(0,len(p)):
			pointsAll.append(p[i]);

	# 产生交点，放在vertexPointSet里
	for i,s in enumerate(streetList):
		if i == (len(streetList) -1):break;
		points = s.streetPoints;
		for i in range(0,len(points)-1):
			v = findVertex(points[i],points[i+1],streetList[i+1])
			for i in range(0,len(v)):
				vertexPointSet.append(v[i]);



def findVertex(A,B,street):
	vex = [];
	points = street.streetPoints
	for i in range(0,len(points)-1):
		if IS.is_intersected(A, B, points[i], points[i+1]):
			p = IS.findIntersectionPoint(A,B,C,D);
			vex.append(p);
	return vex


def getKs(streetList):
	ks = [];
	for s in streetList:
		points = s.streetPoints;
		plenth = len(points);
		for i in range(0,plenth-1):
			k = calK(points[i],points[i+1]);
			ks.append(k);
	return ks

def isConnected(A,B):
	return calDistance(A,B) 



def calDistance(A,B):
	return math.sqrt(np.square(A.x - B.x) + np.square(A.y - B.y))

def calK(A,B):
	if A.x == B.x:
		return 1000000;
	else:
		return (A.y - B.y)/(A.x - B.x)


def point_str2class(str):
	str = str[1:-1];
	a,b = str.split(',');
	x,y = float(a),float(b);
	return IS.Point(x,y);

def readInput(s):
	s_list = s.split(' ');
	command = s_list[0];
	str = s_list[1];
	pl = s_list[2:];
	pointList = [];
	for pointStr in pl:
		pointList.append(point_str2class(pointStr));


	return command,str,pointList

streetList = [];
# while True:
	
# 	s = input();
# 	command,str,pointList = readInput(s);
# 	if command == 'a':
# 		streetList.append(a(str,pointList));
# 	elif command == 'c':
# 		c(streetList,str,pointList);
# 	elif command == 'r':
# 		r(streetList,str);

# 	for s in streetList:
# 		print(s.streetName,s.streetPoints)

s1 = 'a "weber" (2,-1) (2,2) (5,5) (5,6) (3,8)'
s2 = 'a "king" (4,2) (4,8)'
s3 = 'a "daven" (1,4) (5,8)'
ss = [];
ss.append(s1);
ss.append(s2);
ss.append(s3);
for i in range(0,len(ss)):
	command,str,pointList = readInput(ss[i]);
	if command == 'a':
		streetList.append(a(str,pointList));
	elif command == 'c':
		c(streetList,str,pointList);
	elif command == 'r':
		r(streetList,str);

	for s in streetList:
		print(s);
s = streetList[0];
print(s.streetName);
a = s.streetPoints;
print(a[0])

# a = findVertex(A,B,streetList[1])

# vertexPointSet=[];
# for i,s in enumerate(streetList):
# 	if i == (len(streetList) -1):break;
# 	points = s.streetPoints;
# 	for i in range(0,len(points)-1):
# 		v = findVertex(points[i],points[i+1],streetList[i+1])
# 		for i in range(0,len(v)):
# 			vertexPointSet.append(v[i]);
## 1 test of intersection

# A = IS.Point(2,4)
# B = IS.Point(2,0)
# C = IS.Point(0,0)
# D = IS.Point(5,2)
# print(IS.is_intersected(A,B,C,D));
# if IS.is_intersected(A,B,C,D):
# 	xpp,ypp = IS.calculateIntersectionPoint(A,B,C,D)
# 	print(xpp,ypp)


## 2 test func of a()

# streetList = [];
# s = 'a "king" (1,2) (2,3) (3,4)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# s = 'a "hello" (1,2) (2,3) (3,4) (0,0) (3,2)';
# command,str,pointList = readInput(s);
# streetList.append(a(str,pointList));

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 3 test func of c()

# s = 'c "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'c':
# 	c(streetList,str,pointList);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)

## 4 test func of r()

# s = 'r "hello" (-1,-1) (-2,-2)';
# command,str,pointList = readInput(s);
# if command == 'r':
# 	r(streetList,str);

# for s in streetList:
# 	print(s.streetName)
# 	print(s.streetPoints)
# Out:
# <__main__.Street object at 0x1100f5400>
# <__main__.Street object at 0x1100f5400>
# <__main__.Street object at 0x1100f5208>
# <__main__.Street object at 0x1100f5400>
# <__main__.Street object at 0x1100f5208>
# <__main__.Street object at 0x1100db710>
# "weber"
# <intersection.Point object at 0x1101418d0>
